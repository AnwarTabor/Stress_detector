# %% [markdown]
# # Exploratory Data Analysis
#
# This notebook explores the raw physiological data from WESAD, SRAD, and SWELL datasets.

# %%
import sys
sys.path.append('..')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from src.data.load_wesad import load_wesad_subject
from src.utils.visualization import plot_signals

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
