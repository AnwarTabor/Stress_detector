# %% [markdown]
# # Baseline Models
#
# Training and evaluation of classical ML models (Random Forest, SVM, etc.)

# %%
import sys
sys.path.append('..')

import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

from src.models.train_baseline import train_baseline_model
from src.evaluation.loso import leave_one_subject_out
from src.evaluation.metrics import calculate_metrics

# %load_ext autoreload
# %autoreload 2
