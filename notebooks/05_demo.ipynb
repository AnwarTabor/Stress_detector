# %% [markdown]
# # Demo
#
# Interactive demonstration of the stress detection system.

# %%
import sys
sys.path.append('..')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from src.utils.visualization import plot_signals

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
