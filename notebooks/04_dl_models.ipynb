# %% [markdown]
# # Deep Learning Models
#
# Training and evaluation of CNN, LSTM, and Transformer models.

# %%
import sys
sys.path.append('..')

import numpy as np
import torch
import torch.nn as nn

from src.models.cnn_model import StressCNN
from src.models.lstm_model import StressLSTM
from src.models.transformer_model import StressTransformer
from src.models.train_dl import train_deep_model

# %load_ext autoreload
# %autoreload 2
